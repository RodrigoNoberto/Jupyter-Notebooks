# %% [markdown]
# # Exploratory Data Analysis using Pandas, Matplotlib and SQL(pandasql)

# %%
# importing libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from pandasql import sqldf

# %%
# importing the dataframe
df = pd.read_csv('automobileEDA.csv')
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
# querying the audi's cars
q = """select * from df where make = 'audi' """
sqldf(q)
# Out:
#    symboling  normalized-losses  make aspiration num-of-doors body-style  \
# 0          2                164  audi        std         four      sedan
# 1          2                164  audi        std         four      sedan
# 2          2                122  audi        std          two      sedan
# 3          1                158  audi        std         four      sedan
# 4          1                122  audi        std         four      wagon
# 5          1                158  audi      turbo         four      sedan
#
#   drive-wheels engine-location  wheel-base    length  ...  compression-ratio  \
# 0          fwd           front        99.8  0.848630  ...               10.0
# 1          4wd           front        99.4  0.848630  ...                8.0
# 2          fwd           front        99.8  0.851994  ...                8.5
# 3          fwd           front       105.8  0.925997  ...                8.5
# ...

# %%
# Car makes where the price of the veicules is bigger than 20,000
q = """select distinct(make) from df where price > 20000 """
sqldf(q)
# Out:
#             make
# 0           audi
# 1            bmw
# 2         jaguar
# 3  mercedes-benz
# 4        porsche
# 5          volvo

# %%
# shape of the dataframe / 201 rows and 29 columns
df.shape
# Out:
# (201, 29)

# %%
# top 10 most expensive cars
q = """select * from df order by price desc limit 10"""
sqldf(q)
# Out:
#    symboling  normalized-losses           make aspiration num-of-doors  \
# 0          1                122  mercedes-benz        std          two
# 1          0                122            bmw        std          two
# 2          0                122  mercedes-benz        std         four
# 3          3                122        porsche        std          two
# 4          0                122            bmw        std         four
# 5          0                122         jaguar        std          two
# 6          0                122         jaguar        std         four
# 7          3                142  mercedes-benz        std          two
# 8         -1                122  mercedes-benz        std         four
# 9          3                122        porsche        std          two
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0      hardtop          rwd           front       112.0  0.957232  ...
# ...

# %%
# average price of every make
q = """select make, avg(price) as 'avg_price' from df group by make order by avg(price) desc"""
sqldf(q)
# Out:
#              make     avg_price
# 0          jaguar  34600.000000
# 1   mercedes-benz  33647.000000
# 2         porsche  31400.500000
# 3             bmw  26118.750000
# 4           volvo  18063.181818
# 5            audi  17859.166667
# 6         mercury  16503.000000
# 7     alfa-romero  15498.333333
# 8          peugot  15489.090909
# 9            saab  15223.333333
# 10          mazda  10652.882353
# 11         nissan  10415.666667
# 12     volkswagen  10077.500000
# 13         toyota   9885.812500
# 14        renault   9595.000000
# 15     mitsubishi   9239.769231
# 16          isuzu   8916.500000
# 17         subaru   8541.250000
# 18          honda   8184.692308
# 19       plymouth   7963.428571
# 20          dodge   7875.444444
# 21      chevrolet   6007.000000

# %%
# types of every column
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
plt.scatter(df['price'],df['engine-size'])
plt.xlabel('Price')
plt.ylabel('Engine-size')
plt.show()

# %%
plt.scatter(df['price'],df['horsepower'],color='g')
plt.xlabel('Price')
plt.ylabel('Horsepower')
plt.show()

# %%
# new dataframe with only 'make' and 'price' columns from the original one
df2 = df[['make', 'price']]
df2.head()
# Out:
#           make    price
# 0  alfa-romero  13495.0
# 1  alfa-romero  16500.0
# 2  alfa-romero  16500.0
# 3         audi  13950.0
# 4         audi  17450.0

# %%
df2.groupby(['make']).size().plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='make'>

# %%
# new dataframe with only the above makes
makes = ['audi', 'bmw', 'mercedes-benz']
df3 = df.loc[df['make'].isin(makes)]
df3['make'].unique()
# Out:
# array(['audi', 'bmw', 'mercedes-benz'], dtype=object)

# %%
df3.groupby(['make']).sum().plot(kind='pie', y='price')
# Out:
# <AxesSubplot:ylabel='price'>
